# %% [markdown]
# # GEE NASA GPM IMERG Downloader (v07 Final Run)
# Notebook ini didesain khusus dan modular untuk mengunduh produk presipitasi satelit global standar emas dunia **NASA GPM IMERG v07 (Integrated Multi-satellitE Retrievals for GPM)** dari Google Earth Engine (GEE):
#
# ### Koleksi & Spesifikasi:
# 1. **IMERG Bulanan Final Run:** `NASA/GPM_L3/IMERG_MONTHLY_V07`
#    - **Variabel Utama:** `precipitation` (laju rerata mm/hari $\rightarrow$ diakumulasi ke total mm/bulan)
#    - **Variabel Kualitas & Kalibrasi:** `gaugeRelativeWeighting`, `precipitationQualityIndex`, `randomError`
#    - **Resolusi Spasial:** $0.10^\circ \times 0.10^\circ$ ($\sim 11.1\text{ km}$)
#    - **Cakupan Temporal:** Januari 1998 s.d. Sekarang (Era TRMM hingga GPM)
# 2. **IMERG Setengah Jam (Half-Hourly):** `NASA/GPM_L3/IMERG_V07`
#    - **Variabel:** `precipitation` (mm/jam), `MWprecipitation` (PMW murni), `IRprecipitation` (IR murni)
#    - **Mode Agregasi:** Agregasi Harian (Daily Accumulation) per bulan (28--31 band $\le 1024$ band)
#
# ### Fitur Utama Sesuai Project Rules:
# - **Dual Environment Compatibility:** Otomatis mendeteksi eksekusi di **Lokal** (via Service Account JSON) maupun **Kaggle Notebooks** (via `KAGGLE_KERNEL_RUN_TYPE` & `kaggle_secrets`).
# - **Vector Boundary & BBox Safety Buffer (Rule 1):** Ekstraksi poligon `33.05_kecamatan.geojson` dengan pembersihan 2D dan penambahan buffer $\pm 0.01^\circ$.
# - **Multi-Band Stacking (`toBands()` - Rule 3):** Mempercepat throughput API hingga 30x lipat tanpa *rate-limit*.
# - **Hierarchical Data Architecture (Rule 3):** Disimpan rapi pada struktur `data/imerg_monthly/<tahun>/imerg_monthly_<tahun>_<bulan>.nc`.
# - **Visual Quick-Check:** Menampilkan peta spasial klimatologi Kebumen dan perbandingan deret waktu.

# %%
# =========================================================================
# 0. INSTALASI DEPENDENSI (JIKA DI RUN DI KAGGLE / ENVIRONMENT BARU)
# =========================================================================
# !pip install geemap earthengine-api rioxarray geopandas xarray netCDF4 matplotlib --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.4/72.4 kB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 37.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 89.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 46.3 MB/s eta 0:00:00

# %%
# =========================================================================
# 1. IMPORT MODUL & PENGATURAN DIREKTORI DINAMIS
# =========================================================================
import ee
import geopandas as gpd
import geemap
from shapely.validation import make_valid
from shapely.ops import transform, unary_union
import os
import shutil
import glob
import rioxarray as rxr
import xarray as xr
import pandas as pd
import numpy as np
import calendar
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

BASE_DIR = os.getcwd()

# Deteksi Lokasi File GeoJSON Administrasi Kebumen
if 'KAGGLE_KERNEL_RUN_TYPE' in os.environ:
    file_geojson = "/kaggle/input/datasets/jerismeteo/projek-downscale/33.05_kecamatan.geojson"
    if not os.path.exists(file_geojson):
        found_geo = glob.glob("/kaggle/input/**/33.05_kecamatan.geojson", recursive=True)
        file_geojson = found_geo[0] if found_geo else os.path.join(BASE_DIR, "33.05_kecamatan.geojson")
else:
    file_geojson = os.path.join(BASE_DIR, "33.05_kecamatan.geojson")

# Struktur Folder Hierarkis (Rule 3)
FOLDER_IMERG_MONTHLY = os.path.join(BASE_DIR, "data", "imerg_monthly")
FOLDER_IMERG_DAILY = os.path.join(BASE_DIR, "data", "imerg_daily")

# Lokasi Smart Cache jika data sudah tersedia di Input Dataset Kaggle
KAGGLE_IMERG_INPUT = "/kaggle/input/datasets/jerismeteo/gee-imerg-kebumen/data"

TAHUN_AWAL = 2000
TAHUN_AKHIR = 2025

print(f"📌 File Batas Wilayah GeoJSON : {file_geojson}")
print(f"📌 Direktori Output IMERG Bln : {FOLDER_IMERG_MONTHLY}")
print(f"📌 Direktori Output IMERG Hrn : {FOLDER_IMERG_DAILY}")
print(f"📌 Target Rentang Tahun       : {TAHUN_AWAL} s.d. {TAHUN_AKHIR}")
# Out:
# 📌 File Batas Wilayah GeoJSON : /kaggle/input/datasets/jerismeteo/projek-downscale/33.05_kecamatan.geojson
# 📌 Direktori Output IMERG Bln : /kaggle/working/data/imerg_monthly
# 📌 Direktori Output IMERG Hrn : /kaggle/working/data/imerg_daily
# 📌 Target Rentang Tahun       : 2000 s.d. 2025

# %%
# =========================================================================
# 2. INISIALISASI GOOGLE EARTH ENGINE (GEE)
# Mendukung: 1. Service Account Lokal (.json) | 2. Kaggle Secrets (GEE_KEY) | 3. Fallback Auth
# =========================================================================
import os
import json
import ee
from google.oauth2.service_account import Credentials

PROJECT_ID = 'staklimjerukagung'
init_success = False

# 1. Coba via Service Account File Lokal (Repo Projek_Downscale)
sa_candidates = [
    os.path.join(BASE_DIR, 'staklimjerukagung-b852a12a367e.json'),
    os.path.join(os.path.dirname(BASE_DIR), 'staklimjerukagung-b852a12a367e.json'),
    'staklimjerukagung-b852a12a367e.json'
]
for sa_path in sa_candidates:
    if os.path.exists(sa_path):
        try:
            with open(sa_path, 'r') as f:
                sa_info = json.load(f)
            SCOPES = ['https://www.googleapis.com/auth/earthengine']
            creds = Credentials.from_service_account_info(sa_info, scopes=SCOPES)
            ee.Initialize(credentials=creds, project=sa_info.get('project_id', PROJECT_ID))
            print(f"✅ Berhasil Inisialisasi GEE via File Service Account Lokal: {os.path.basename(sa_path)}")
            init_success = True
            break
        except Exception as e:
            print(f"⚠️ Gagal inisialisasi via SA file {sa_path}: {e}")

# 2. Coba via Kaggle User Secrets (Kaggle Environment: Add-ons -> Secrets -> GEE_KEY)
if not init_success:
    try:
        from kaggle_secrets import UserSecretsClient
        user_secrets = UserSecretsClient()
        sa_json_str = user_secrets.get_secret('GEE_KEY')
        sa_info = json.loads(sa_json_str)
        SCOPES = ['https://www.googleapis.com/auth/earthengine']
        creds = Credentials.from_service_account_info(sa_info, scopes=SCOPES)
        ee.Initialize(credentials=creds, project=sa_info.get('project_id', PROJECT_ID))
        print("✅ Berhasil Inisialisasi GEE via Kaggle Secret (GEE_KEY)")
        init_success = True
    except Exception as e:
        print(f"⚠️ Info Kaggle Secrets: {e}")
        print("💡 Tips di Kaggle: Buka menu Add-ons -> Secrets -> pastikan centang (checkbox) pada 'GEE_KEY' di notebook ini!")

# 3. Fallback ke Inisialisasi Default / Browser OAuth
if not init_success:
    try:
        ee.Initialize(project=PROJECT_ID)
        print("✅ Berhasil Inisialisasi GEE via Session Default")
    except Exception as e:
        print(f"ℹ️ Inisialisasi default gagal ({e}), membuka otentikasi browser GEE...")
        ee.Authenticate()
        ee.Initialize(project=PROJECT_ID)
        print("✅ Berhasil Autentikasi & Inisialisasi GEE via Browser")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ✅ Berhasil Inisialisasi GEE via Kaggle Secret (GEE_KEY)

# %%
# =========================================================================
# 3. PERSIAPAN GEOMETRI & BOUNDING BOX (RULE 1)
# =========================================================================
if not os.path.exists(file_geojson):
    raise FileNotFoundError(f"File GeoJSON tidak ditemukan: {file_geojson}")

gdf = gpd.read_file(file_geojson)
if gdf.crs != "EPSG:4326":
    gdf = gdf.to_crs("EPSG:4326")

print("Membersihkan topologi geometri...")
gdf = gdf[gdf.geometry.notna()].copy()

def _to_2d(geom):
    if geom is None or geom.is_empty: return None
    return transform(lambda x, y, z=None: (x, y), geom)

def _clean_geom(geom):
    if geom is None or geom.is_empty: return None
    geom = _to_2d(geom)
    geom = make_valid(geom)
    if geom is None or geom.is_empty: return None
    return geom.buffer(0)

gdf["geometry"] = gdf["geometry"].apply(_clean_geom)
gdf = gdf[gdf.geometry.notna() & ~gdf.geometry.is_empty].copy()
gdf = gdf[gdf.geom_type.isin(["Polygon", "MultiPolygon"])].copy()
gdf.reset_index(drop=True, inplace=True)

print("Mengonversi ke Google Earth Engine FeatureCollection...")
geojson_fc = gdf.__geo_interface__
batas_kebumen = ee.FeatureCollection(geojson_fc["features"])

# Ekstraksi BBox dengan Safety Buffer (Rule 1)
bounds = gdf.total_bounds
BUFFER_DEG = 0.02
ee_bbox = ee.Geometry.BBox(
    bounds[0] - BUFFER_DEG,  # min Lon (West)
    bounds[1] - BUFFER_DEG,  # min Lat (South)
    bounds[2] + BUFFER_DEG,  # max Lon (East)
    bounds[3] + BUFFER_DEG   # max Lat (North)
)

print(f"✅ Batas Geometri Siap!")
print(f"   Extent Asli: Lon [{bounds[0]:.4f}, {bounds[2]:.4f}], Lat [{bounds[1]:.4f}, {bounds[3]:.4f}]")
print(f"   Extent BBox: Lon [{bounds[0]-BUFFER_DEG:.4f}, {bounds[2]+BUFFER_DEG:.4f}], Lat [{bounds[1]-BUFFER_DEG:.4f}, {bounds[3]+BUFFER_DEG:.4f}]")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Membersihkan topologi geometri...
# Mengonversi ke Google Earth Engine FeatureCollection...
# ✅ Batas Geometri Siap!
#    Extent Asli: Lon [109.3788, 109.8393], Lat [-7.8312, -7.4457]
#    Extent BBox: Lon [109.3588, 109.8593], Lat [-7.8512, -7.4257]

# %%
# =========================================================================
# 4. FUNGSI UNDUH SUPER-CEPAT GPM IMERG BULANAN (FINAL RUN V07)
# =========================================================================
def unduh_imerg_bulanan(tahun, output_base_dir):
    """
    Mengunduh 12 bulan presipitasi bulanan NASA GPM IMERG v07 Final Run
    menggunakan teknik Multi-Band Stacking (toBands()) dalam satu kali request.
    """
    folder_tahun = os.path.join(output_base_dir, str(tahun))
    os.makedirs(folder_tahun, exist_ok=True)
    
    nc_out_path = os.path.join(folder_tahun, f"imerg_monthly_{tahun}.nc")
    tif_temp_path = os.path.join(folder_tahun, f"imerg_monthly_{tahun}_temp.tif")
    
    if os.path.exists(nc_out_path):
        print(f"[{tahun}] ✓ File NetCDF tahunan sudah ada: {nc_out_path}")
        return nc_out_path
        
    tgl_awal = f"{tahun}-01-01"
    tgl_akhir = f"{tahun+1}-01-01"
    
    print(f"[{tahun}] Mengambil koleksi IMERG Monthly V07 dari GEE...")
    col = (ee.ImageCollection("NASA/GPM_L3/IMERG_MONTHLY_V07")
           .filterBounds(ee_bbox)
           .filterDate(tgl_awal, tgl_akhir))
    
    n_img = col.size().getInfo()
    if n_img == 0:
        print(f"[{tahun}] ⚠️ Tidak ada data IMERG di GEE untuk tahun ini.")
        return None
        
    # Ambil timestamps
    times_ms = col.aggregate_array('system:time_start').getInfo()
    time_index = pd.to_datetime(times_ms, unit='ms')
    
    # Seleksi band presipitasi (dalam mm/hari) dan konversi ke mm/bulan (x jumlah hari)
    def convert_to_monthly_accum(img):
        # Ambil tanggal untuk menghitung jumlah hari dalam bulan tersebut
        date = ee.Date(img.get('system:time_start'))
        # days in month = date.advance(1, 'month').difference(date, 'day')
        days = date.advance(1, 'month').difference(date, 'day')
        rate_mm_day = img.select('precipitation')
        monthly_mm = rate_mm_day.multiply(days).rename('precipitation_monthly_mm')
        return monthly_mm.copyProperties(img, ['system:time_start'])
        
    monthly_col = col.map(convert_to_monthly_accum)
    stacked = monthly_col.toBands().clip(ee_bbox)
    
    print(f"[{tahun}] Mengekspor {n_img} bulan sekaligus ke GeoTIFF temporer...")
    geemap.ee_export_image(
        stacked,
        filename=tif_temp_path,
        region=ee_bbox,
        scale=11132,  # Resolusi asli ~0.10 derajat (11 km)
        file_per_band=False
    )
    
    print(f"[{tahun}] Mengonversi GeoTIFF -> NetCDF Time-Series...")
    with rxr.open_rasterio(tif_temp_path, masked=True) as da:
        da = da.rename({'band': 'time'})
        da['time'] = time_index[:len(da.time)]
        da.name = "precipitation"
        da.attrs["long_name"] = "NASA GPM IMERG v07 Final Run Monthly Accumulated Precipitation"
        da.attrs["units"] = "mm/month"
        da.attrs["source"] = "NASA/GPM_L3/IMERG_MONTHLY_V07"
        da.to_netcdf(nc_out_path)
        
    if os.path.exists(tif_temp_path): os.remove(tif_temp_path)
    print(f"[{tahun}] ✓ Sukses! Tersimpan di: {nc_out_path}\n")
    return nc_out_path
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# =========================================================================
# 5. FUNGSI UNDUH IMERG HARIAN AGREGASI (DAILY ACCUMULATION V07)
# =========================================================================
def unduh_imerg_harian_bulanan(tahun, bulan, output_base_dir):
    """
    Mengunduh presipitasi harian (mm/hari) selama 1 bulan penuh
    diagregasikan dari koleksi 30-menit NASA/GPM_L3/IMERG_V07.
    Menggunakan 28-31 band per bulan (jauh di bawah limit 1024 band GEE).
    """
    folder_tahun = os.path.join(output_base_dir, str(tahun))
    os.makedirs(folder_tahun, exist_ok=True)
    
    nc_path = os.path.join(folder_tahun, f"imerg_daily_{tahun}_{bulan:02d}.nc")
    tif_temp = os.path.join(folder_tahun, f"imerg_daily_{tahun}_{bulan:02d}_temp.tif")
    
    if os.path.exists(nc_path):
        print(f"[{tahun}-{bulan:02d}] ✓ File harian sudah ada: {nc_path}")
        return nc_path
        
    num_days = calendar.monthrange(tahun, bulan)[1]
    daily_images = []
    dates_list = []
    
    print(f"[{tahun}-{bulan:02d}] Mengompilasi agregasi harian ({num_days} hari) dari citra 30-menit...")
    for day in range(1, num_days + 1):
        t_start = f"{tahun}-{bulan:02d}-{day:02d}"
        if day == num_days:
            if bulan == 12:
                t_end = f"{tahun+1}-01-01"
            else:
                t_end = f"{tahun}-{bulan+1:02d}-01"
        else:
            t_end = f"{tahun}-{bulan:02d}-{day+1:02d}"
            
        sub_col = (ee.ImageCollection("NASA/GPM_L3/IMERG_V07")
                   .filterBounds(ee_bbox)
                   .filterDate(t_start, t_end)
                   .select('precipitation'))
        
        # Laju curah hujan rata-rata (mm/jam) * 24 jam = total presipitasi harian (mm/hari)
        daily_img = sub_col.mean().multiply(24.0).rename(f"p_day_{day:02d}")
        daily_images.append(daily_img)
        dates_list.append(pd.to_datetime(t_start))
        
    # Stack 28-31 band harian menjadi 1 citra multi-band
    stacked_daily = ee.ImageCollection(daily_images).toBands().clip(ee_bbox)
    
    print(f"[{tahun}-{bulan:02d}] Mengekspor citra multi-band harian ke TIF...")
    geemap.ee_export_image(
        stacked_daily,
        filename=tif_temp,
        region=ee_bbox,
        scale=11132,
        file_per_band=False
    )
    
    print(f"[{tahun}-{bulan:02d}] Menyusun NetCDF Harian Time-Series...")
    with rxr.open_rasterio(tif_temp, masked=True) as da:
        da = da.rename({'band': 'time'})
        da['time'] = dates_list[:len(da.time)]
        da.name = "precipitation"
        da.attrs["long_name"] = "Daily Precipitation (Aggregated from 30-min GPM IMERG v07)"
        da.attrs["units"] = "mm/day"
        da.to_netcdf(nc_path)
        
    if os.path.exists(tif_temp): os.remove(tif_temp)
    print(f"[{tahun}-{bulan:02d}] ✓ Selesai! NetCDF Harian: {nc_path}\n")
    return nc_path
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# =========================================================================
# 6. EKSEKUSI BATCH PENGUNDUHAN MULTI-TAHUN IMERG BULANAN (2000 - 2025)
# =========================================================================
print("=" * 75)
print(f"🚀 MEMULAI PIPELINE BATCH PENGUNDUHAN GPM IMERG BULANAN ({TAHUN_AWAL} - {TAHUN_AKHIR})")
print("=" * 75)

downloaded_files = []
for thn in range(TAHUN_AWAL, TAHUN_AKHIR + 1):
    path_res = unduh_imerg_bulanan(thn, FOLDER_IMERG_MONTHLY)
    if path_res:
        downloaded_files.append(path_res)

print("=" * 75)
print(f"🎉 SELESAI PENGUNDUHAN BATCH: {len(downloaded_files)} TAHUN FILE NETCDF TERSEDIA!")
print("=" * 75)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ===========================================================================
# 🚀 MEMULAI PIPELINE BATCH PENGUNDUHAN GPM IMERG BULANAN (2000 - 2025)
# ===========================================================================
# [2000] Mengambil koleksi IMERG Monthly V07 dari GEE...
# [2000] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/b057c2e2e02965ddfff1e616c72f4d09-5674e67941f40f8299f63adee39283b4:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2000/imerg_monthly_2000_temp.tif
# [2000] Mengonversi GeoTIFF -> NetCDF Time-Series...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2000] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2000/imerg_monthly_2000.nc
#
# [2001] Mengambil koleksi IMERG Monthly V07 dari GEE...
# [2001] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/cee0ae69a198a84682c7dfd2956065e3-1ccce832256e4cc0c91f6b1082b8384f:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2001/imerg_monthly_2001_temp.tif
# [2001] Mengonversi GeoTIFF -> NetCDF Time-Series...
# [2001] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2001/imerg_monthly_2001.nc
#
# [2002] Mengambil koleksi IMERG Monthly V07 dari GEE...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2002] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/53daed2f8ba003eda8e787070c7c0049-4a4a215a5d378b094cd2c92324fb0866:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2002/imerg_monthly_2002_temp.tif
# [2002] Mengonversi GeoTIFF -> NetCDF Time-Series...
# [2002] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2002/imerg_monthly_2002.nc
#
# [2003] Mengambil koleksi IMERG Monthly V07 dari GEE...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2003] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/25831845218c67d41127a590c42c4d58-9960af58d3dfaee3e7f6989f06408483:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2003/imerg_monthly_2003_temp.tif
# [2003] Mengonversi GeoTIFF -> NetCDF Time-Series...
# [2003] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2003/imerg_monthly_2003.nc
#
# [2004] Mengambil koleksi IMERG Monthly V07 dari GEE...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2004] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/ebe2728f970f223db09afba770daa3d3-d69a84c9d4ae6e166a4323a69e42dd98:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2004/imerg_monthly_2004_temp.tif
# [2004] Mengonversi GeoTIFF -> NetCDF Time-Series...
# [2004] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2004/imerg_monthly_2004.nc
#
# [2005] Mengambil koleksi IMERG Monthly V07 dari GEE...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2005] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/735cd055eedcbceddd2cd8f7c415fe88-efe54dadb1ebe607eb3823f9d207d8c8:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2005/imerg_monthly_2005_temp.tif
# [2005] Mengonversi GeoTIFF -> NetCDF Time-Series...
# [2005] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2005/imerg_monthly_2005.nc
#
# [2006] Mengambil koleksi IMERG Monthly V07 dari GEE...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2006] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/0b8fb770045095158cbf31bcf12e6216-331f2f4dca29187599692791db810007:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2006/imerg_monthly_2006_temp.tif
# [2006] Mengonversi GeoTIFF -> NetCDF Time-Series...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2006] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2006/imerg_monthly_2006.nc
#
# [2007] Mengambil koleksi IMERG Monthly V07 dari GEE...
# [2007] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/3eef2cd324d5d1b3b89aad9b8b032431-5b6d3fbdb7cda6538e7662f5b8ba0437:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2007/imerg_monthly_2007_temp.tif
# [2007] Mengonversi GeoTIFF -> NetCDF Time-Series...
# [2007] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2007/imerg_monthly_2007.nc
#
# [2008] Mengambil koleksi IMERG Monthly V07 dari GEE...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2008] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/0e3785aa127cf1525b896bb796cf9345-20508d9b2e3f99852e9cb691ddd43f98:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2008/imerg_monthly_2008_temp.tif
# [2008] Mengonversi GeoTIFF -> NetCDF Time-Series...
# [2008] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2008/imerg_monthly_2008.nc
#
# [2009] Mengambil koleksi IMERG Monthly V07 dari GEE...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2009] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/df46c87f69f22b615a069dbda579c69f-9407341d01ee5d3e9596f70105b1d949:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2009/imerg_monthly_2009_temp.tif
# [2009] Mengonversi GeoTIFF -> NetCDF Time-Series...
# [2009] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2009/imerg_monthly_2009.nc
#
# [2010] Mengambil koleksi IMERG Monthly V07 dari GEE...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2010] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/0e3c6b6e73df1b383a7c9ca844af241a-dd8f609aaef5603ff39cd616fe07575d:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2010/imerg_monthly_2010_temp.tif
# [2010] Mengonversi GeoTIFF -> NetCDF Time-Series...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2010] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2010/imerg_monthly_2010.nc
#
# [2011] Mengambil koleksi IMERG Monthly V07 dari GEE...
# [2011] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/8d9599e06e267f00fc8c4dbacbed91b3-e4f179d439b2899e84140bcb1b8cd992:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2011/imerg_monthly_2011_temp.tif
# [2011] Mengonversi GeoTIFF -> NetCDF Time-Series...
# [2011] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2011/imerg_monthly_2011.nc
#
# [2012] Mengambil koleksi IMERG Monthly V07 dari GEE...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2012] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/e2ae0c16e7732cc79d6e49c25445c9aa-e6356afa13d4cb15c41e6f720b2719c0:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2012/imerg_monthly_2012_temp.tif
# [2012] Mengonversi GeoTIFF -> NetCDF Time-Series...
# [2012] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2012/imerg_monthly_2012.nc
#
# [2013] Mengambil koleksi IMERG Monthly V07 dari GEE...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2013] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/fff4a913feeef35e45c2586bc5c7bba6-0860c824e03402d1c76ea6503c168384:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2013/imerg_monthly_2013_temp.tif
# [2013] Mengonversi GeoTIFF -> NetCDF Time-Series...
# [2013] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2013/imerg_monthly_2013.nc
#
# [2014] Mengambil koleksi IMERG Monthly V07 dari GEE...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2014] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/dda4f68186964376a48f1729e86555d8-e88f37fcf126091f14690d10f75b7b24:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2014/imerg_monthly_2014_temp.tif
# [2014] Mengonversi GeoTIFF -> NetCDF Time-Series...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2014] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2014/imerg_monthly_2014.nc
#
# [2015] Mengambil koleksi IMERG Monthly V07 dari GEE...
# [2015] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/c54f7efa2ab1dd8452b44bda3e5cf326-461a83d276f2852ad29e731c5d498afb:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2015/imerg_monthly_2015_temp.tif
# [2015] Mengonversi GeoTIFF -> NetCDF Time-Series...
# [2015] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2015/imerg_monthly_2015.nc
#
# [2016] Mengambil koleksi IMERG Monthly V07 dari GEE...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2016] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/a451292fad844e3213c92c756fff3352-b239d183422ec72a82a8dabf4a58bbd6:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2016/imerg_monthly_2016_temp.tif
# [2016] Mengonversi GeoTIFF -> NetCDF Time-Series...
# [2016] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2016/imerg_monthly_2016.nc
#
# [2017] Mengambil koleksi IMERG Monthly V07 dari GEE...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2017] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/482a23bd8728e71704f10789e775556f-e78f911372ff35049145740d151ce145:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2017/imerg_monthly_2017_temp.tif
# [2017] Mengonversi GeoTIFF -> NetCDF Time-Series...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2017] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2017/imerg_monthly_2017.nc
#
# [2018] Mengambil koleksi IMERG Monthly V07 dari GEE...
# [2018] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/8e396ad09b8d852d605cbd15849c1c1c-d6245f4301cfa64d6d74bf4595e8278f:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2018/imerg_monthly_2018_temp.tif
# [2018] Mengonversi GeoTIFF -> NetCDF Time-Series...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2018] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2018/imerg_monthly_2018.nc
#
# [2019] Mengambil koleksi IMERG Monthly V07 dari GEE...
# [2019] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/f456f887130e939fa05000b218ff43cd-c91cc8c3b4fadcd929fdc61b4f1296fd:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2019/imerg_monthly_2019_temp.tif
# [2019] Mengonversi GeoTIFF -> NetCDF Time-Series...
# [2019] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2019/imerg_monthly_2019.nc
#
# [2020] Mengambil koleksi IMERG Monthly V07 dari GEE...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2020] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/8c33108d20ba01de8c1e804772d97648-8e5f6f927017a180bc7ce9e95b2768b1:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2020/imerg_monthly_2020_temp.tif
# [2020] Mengonversi GeoTIFF -> NetCDF Time-Series...
# [2020] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2020/imerg_monthly_2020.nc
#
# [2021] Mengambil koleksi IMERG Monthly V07 dari GEE...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2021] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/b0f62e0b84db84a614165b16816e6053-83eca3602dfc01fda29fa975de5477f9:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2021/imerg_monthly_2021_temp.tif
# [2021] Mengonversi GeoTIFF -> NetCDF Time-Series...
# [2021] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2021/imerg_monthly_2021.nc
#
# [2022] Mengambil koleksi IMERG Monthly V07 dari GEE...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2022] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/b2361d7c174f2cfc98a44d15b80ff56e-70fcde2e458f95c62b1f675d6f227993:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2022/imerg_monthly_2022_temp.tif
# [2022] Mengonversi GeoTIFF -> NetCDF Time-Series...
# [2022] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2022/imerg_monthly_2022.nc
#
# [2023] Mengambil koleksi IMERG Monthly V07 dari GEE...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2023] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/07336cc4b0e24f473ca04185cce39463-df8c1b309083ddf28e759f0b9c6e428f:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2023/imerg_monthly_2023_temp.tif
# [2023] Mengonversi GeoTIFF -> NetCDF Time-Series...
# [2023] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2023/imerg_monthly_2023.nc
#
# [2024] Mengambil koleksi IMERG Monthly V07 dari GEE...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2024] Mengekspor 12 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/ab9bc6c872756351eb7f78d3b498fe43-d4afb2ba038cd98678e9d08b6f9a0e31:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2024/imerg_monthly_2024_temp.tif
# [2024] Mengonversi GeoTIFF -> NetCDF Time-Series...
# [2024] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2024/imerg_monthly_2024.nc
#
# [2025] Mengambil koleksi IMERG Monthly V07 dari GEE...
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [2025] Mengekspor 9 bulan sekaligus ke GeoTIFF temporer...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/staklimjerukagung/thumbnails/082b31a46f315cf76e23450e5a0ac683-06815600e5bf72a3fd367e53e1d8092a:getPixels
# Please wait ...
# Data downloaded to /kaggle/working/data/imerg_monthly/2025/imerg_monthly_2025_temp.tif
# [2025] Mengonversi GeoTIFF -> NetCDF Time-Series...
# [2025] ✓ Sukses! Tersimpan di: /kaggle/working/data/imerg_monthly/2025/imerg_monthly_2025.nc
#
# ===========================================================================
# 🎉 SELESAI PENGUNDUHAN BATCH: 26 TAHUN FILE NETCDF TERSEDIA!
# ===========================================================================
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.

# %%
# =========================================================================
# 7. VERIFIKASI VISUALISASI SPASIAL KLIMATOLOGI IMERG KEBUMEN
# =========================================================================
list_nc = sorted(glob.glob(os.path.join(FOLDER_IMERG_MONTHLY, "*", "*.nc")))

if not list_nc:
    print("ℹ️ Belum ada file NetCDF IMERG yang selesai diunduh untuk divisualisasikan.")
else:
    print(f"Memuat {len(list_nc)} file tahunan NetCDF untuk kalkulasi klimatologi...")
    datasets = [xr.open_dataset(f) for f in list_nc]
    ds_all = xr.concat(datasets, dim="time")
    
    # Total akumulasi tahunan rata-rata (mm/tahun)
    annual_mean = ds_all["precipitation"].resample(time="1YS").sum(dim="time").mean(dim="time")
    
    fig, ax = plt.subplots(figsize=(10, 6), dpi=150)
    p = annual_mean.plot(
        ax=ax,
        cmap="Blues",
        cbar_kwargs={"label": "Presipitasi Tahunan Rerata (mm/tahun)"}
    )
    gdf.boundary.plot(ax=ax, color="black", linewidth=0.8, alpha=0.8)
    ax.set_title(f"Klimatologi Spasial Presipitasi NASA GPM IMERG v07 ({TAHUN_AWAL}--{TAHUN_AKHIR})\nKabupaten Kebumen, Jawa Tengah", fontsize=11, fontweight="bold")
    ax.set_xlabel("Bujur (Longitude)")
    ax.set_ylabel("Lintang (Latitude)")
    ax.grid(True, linestyle="--", alpha=0.5)
    plt.tight_layout()
    plt.show()
    
    # Tutup dataset untuk hemat RAM
    ds_all.close()
    for ds in datasets: ds.close()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Memuat 26 file tahunan NetCDF untuk kalkulasi klimatologi...
# /tmp/ipykernel_16/1814684543.py:11: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   ds_all = xr.concat(datasets, dim="time")
